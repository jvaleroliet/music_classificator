# %% [markdown]
# # Data Collection

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import requests
import os

SPOTIPY_CLIENT_ID='spotify_id'
SPOTIPY_CLIENT_SECRET='spotify_secret'

# %%
cid = SPOTIPY_CLIENT_ID
secret = SPOTIPY_CLIENT_SECRET
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager
=
client_credentials_manager)

# %%
playlists = {"house" : "37i9dQZF1EIeXVd9c2ss7N", }

# %%
playlist_id = "37i9dQZF1EIeXVd9c2ss7N"  # Replace with the playlist's ID
playlist_info = sp.playlist(playlist_id)
playlist_df = pd.json_normalize(playlist_info["tracks"]["items"])

# %%
playlist_links = playlist_df["track.preview_url"].dropna()

# %%
def download_mp3(url, filename):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(filename, 'wb') as f:
            for chunk in response.iter_content(chunk_size=1024):
                if chunk:
                    f.write(chunk)
        print(f"Downloaded {filename}")
    else:
        print(f"Error downloading {url}: {response.status_code}")

# %%
folder_path = "./songs/house"

def create_folder(folder_path):
    """
    Creates a folder at the specified path if it doesn't exist.

    Args:
        folder_path (str): The path of the folder to create.
    """

    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Folder created: {folder_path}")
    else:
        print(f"Folder already exists: {folder_path}")



create_folder(folder_path)

for i, link in enumerate(playlist_links.tolist()):
    filename = f"{folder_path}/preview_{i+1}.mp3"
    download_mp3(link, filename)
    if i==2:
        break
# Out:
# Folder already exists: ./songs/house
# Downloaded ./songs/house/preview_1.mp3
# Downloaded ./songs/house/preview_2.mp3
# Downloaded ./songs/house/preview_3.mp3

# %%
def download_playlist(playlistname, playlisturi):
    folder_path = f"./songs/{playlistname}"
    create_folder(folder_path)
    playlist_info = sp.playlist(playlisturi)
    playlist_df = pd.json_normalize(playlist_info["tracks"]["items"])
    playlist_links = playlist_df["track.preview_url"].dropna()
    for i, link in enumerate(playlist_links.tolist()):
        filename = f"{folder_path}/preview_{i+1}.mp3"
        download_mp3(link, filename)
        if i == 100:
            break

# %% [markdown]
# ## Loop

# %%
playlists = {"house" : "37i9dQZF1EIeXVd9c2ss7N", 
             "techno" : "37i9dQZF1DX6J5NfMJS675", 
             "hardcore_breaks" : "3t5x9cGartT2heiIyqp8gb", 
             "dupstep" : "72agyQnKkBIqgUfwtRPzOB", 
             "psytrance" : "0iJEh2BsvSw8V3lDTkiUK7"}

# %%
for key, value in playlists.items():
    download_playlist(key, value)
# Out:
# Folder already exists: ./songs/house
# Downloaded ./songs/house/preview_1.mp3
# Downloaded ./songs/house/preview_2.mp3
# Downloaded ./songs/house/preview_3.mp3
# Downloaded ./songs/house/preview_4.mp3
# Downloaded ./songs/house/preview_5.mp3
# Downloaded ./songs/house/preview_6.mp3
# Downloaded ./songs/house/preview_7.mp3
# Downloaded ./songs/house/preview_8.mp3
# Downloaded ./songs/house/preview_9.mp3
# Downloaded ./songs/house/preview_10.mp3
# Downloaded ./songs/house/preview_11.mp3
# Downloaded ./songs/house/preview_12.mp3
# Downloaded ./songs/house/preview_13.mp3
# Downloaded ./songs/house/preview_14.mp3
# Downloaded ./songs/house/preview_15.mp3
# Downloaded ./songs/hardcore_breaks/preview_11.mp3
# Downloaded ./songs/hardcore_breaks/preview_12.mp3
# Downloaded ./songs/hardcore_breaks/preview_13.mp3
# Downloaded ./songs/hardcore_breaks/preview_14.mp3
# Downloaded ./songs/hardcore_breaks/preview_15.mp3
# Downloaded ./songs/hardcore_breaks/preview_16.mp3
# Downloaded ./songs/hardcore_breaks/preview_17.mp3
# Downloaded ./songs/hardcore_breaks/preview_18.mp3
# Downloaded ./songs/hardcore_breaks/preview_19.mp3
# Downloaded ./songs/hardcore_breaks/preview_20.mp3
# Downloaded ./songs/hardcore_breaks/preview_21.mp3
# Downloaded ./songs/hardcore_breaks/preview_22.mp3
# Downloaded ./songs/hardcore_breaks/preview_23.mp3
# Downloaded ./songs/hardcore_breaks/preview_24.mp3
# Downloaded ./songs/hardcore_breaks/preview_25.mp3
# Downloaded ./songs/hardcore_breaks/preview_26.mp3
# Downloaded ./songs/hardcore_breaks/preview_27.mp3
# Downloaded ./songs/hardcore_breaks/preview_28.mp3
# Downloaded ./songs/hardcore_breaks/preview_29.mp3
# Downloaded ./songs/hardcore_breaks/preview_30.mp3
# Downloaded ./songs/hardcore_breaks/preview_31.mp3
# Downloaded ./songs/hardcore_breaks/preview_32.mp3
# Downloaded ./songs/hardcore_breaks/preview_33.mp3
# Downloaded ./songs/hardcore_breaks/preview_34.mp3
# Downloaded ./songs/hardcore_breaks/preview_35.mp3
# Downloaded ./songs/hardcore_breaks/preview_36.mp3
# Downloaded ./songs/hardcore_breaks/preview_37.mp3
# Downloaded ./songs/hardcore_breaks/preview_38.mp3
# Downloaded ./songs/hardcore_breaks/preview_39.mp3
# Downloaded ./songs/hardcore_breaks/preview_40.mp3
# Downloaded ./songs/hardcore_breaks/preview_41.mp3
# Downloaded ./songs/hardcore_breaks/preview_42.mp3
# Downloaded ./songs/hardcore_breaks/preview_43.mp3
# Downloaded ./songs/hardcore_breaks/preview_44.mp3
# Downloaded ./songs/hardcore_breaks/preview_45.mp3
# Downloaded ./songs/hardcore_breaks/preview_46.mp3
# Downloaded ./songs/hardcore_breaks/preview_47.mp3
# Downloaded ./songs/hardcore_breaks/preview_48.mp3
# Downloaded ./songs/hardcore_breaks/preview_49.mp3
# Downloaded ./songs/hardcore_breaks/preview_50.mp3
# Downloaded ./songs/hardcore_breaks/preview_51.mp3
# Downloaded ./songs/hardcore_breaks/preview_52.mp3
# Downloaded ./songs/hardcore_breaks/preview_53.mp3
# Downloaded ./songs/hardcore_breaks/preview_54.mp3
# Downloaded ./songs/hardcore_breaks/preview_55.mp3
# Downloaded ./songs/hardcore_breaks/preview_56.mp3
# Downloaded ./songs/hardcore_breaks/preview_57.mp3
# Downloaded ./songs/hardcore_breaks/preview_58.mp3
# Downloaded ./songs/hardcore_breaks/preview_59.mp3
# Folder already exists: ./songs/dupstep
# Downloaded ./songs/dupstep/preview_1.mp3
# Downloaded ./songs/dupstep/preview_2.mp3
# Downloaded ./songs/dupstep/preview_3.mp3
# Downloaded ./songs/dupstep/preview_4.mp3
# Downloaded ./songs/dupstep/preview_5.mp3
# Downloaded ./songs/dupstep/preview_6.mp3
# Downloaded ./songs/dupstep/preview_7.mp3
# Downloaded ./songs/dupstep/preview_8.mp3
# Downloaded ./songs/dupstep/preview_9.mp3
# Downloaded ./songs/dupstep/preview_10.mp3
# Downloaded ./songs/dupstep/preview_11.mp3
# Downloaded ./songs/dupstep/preview_12.mp3
# Downloaded ./songs/dupstep/preview_13.mp3
# Downloaded ./songs/dupstep/preview_14.mp3
# Downloaded ./songs/dupstep/preview_15.mp3
# Downloaded ./songs/dupstep/preview_16.mp3
# Downloaded ./songs/dupstep/preview_17.mp3
# Downloaded ./songs/dupstep/preview_18.mp3
# Downloaded ./songs/dupstep/preview_19.mp3
# Downloaded ./songs/dupstep/preview_20.mp3
# Downloaded ./songs/dupstep/preview_21.mp3
# Downloaded ./songs/dupstep/preview_22.mp3
# Downloaded ./songs/dupstep/preview_23.mp3
# Downloaded ./songs/dupstep/preview_24.mp3
# Downloaded ./songs/dupstep/preview_25.mp3
# Downloaded ./songs/dupstep/preview_26.mp3
# Downloaded ./songs/dupstep/preview_27.mp3
# Downloaded ./songs/dupstep/preview_28.mp3
# Downloaded ./songs/dupstep/preview_29.mp3
# Downloaded ./songs/dupstep/preview_30.mp3
# Downloaded ./songs/dupstep/preview_31.mp3
# Downloaded ./songs/dupstep/preview_32.mp3
# Downloaded ./songs/dupstep/preview_33.mp3
# Downloaded ./songs/dupstep/preview_34.mp3
# Downloaded ./songs/dupstep/preview_35.mp3
# Downloaded ./songs/dupstep/preview_36.mp3
# Downloaded ./songs/dupstep/preview_37.mp3
# Downloaded ./songs/dupstep/preview_38.mp3
# Downloaded ./songs/dupstep/preview_39.mp3
# Downloaded ./songs/dupstep/preview_40.mp3
# Downloaded ./songs/dupstep/preview_41.mp3
# Downloaded ./songs/dupstep/preview_42.mp3
# Downloaded ./songs/dupstep/preview_43.mp3
# Downloaded ./songs/dupstep/preview_44.mp3
# Downloaded ./songs/dupstep/preview_45.mp3
# Downloaded ./songs/dupstep/preview_46.mp3
# Downloaded ./songs/dupstep/preview_47.mp3
# Downloaded ./songs/dupstep/preview_48.mp3
# Downloaded ./songs/dupstep/preview_49.mp3
# Downloaded ./songs/dupstep/preview_50.mp3
# Downloaded ./songs/dupstep/preview_51.mp3
# Downloaded ./songs/dupstep/preview_52.mp3
# Downloaded ./songs/dupstep/preview_53.mp3
# Downloaded ./songs/dupstep/preview_54.mp3
# Downloaded ./songs/dupstep/preview_55.mp3
# Downloaded ./songs/dupstep/preview_56.mp3
# Downloaded ./songs/dupstep/preview_57.mp3
# Downloaded ./songs/dupstep/preview_58.mp3
# Downloaded ./songs/dupstep/preview_59.mp3
# Downloaded ./songs/dupstep/preview_60.mp3
# Downloaded ./songs/dupstep/preview_61.mp3
# Downloaded ./songs/dupstep/preview_62.mp3
# Downloaded ./songs/dupstep/preview_63.mp3
# Downloaded ./songs/dupstep/preview_64.mp3
# Downloaded ./songs/dupstep/preview_65.mp3
# Downloaded ./songs/dupstep/preview_66.mp3
# Downloaded ./songs/dupstep/preview_67.mp3
# Downloaded ./songs/dupstep/preview_68.mp3
# Downloaded ./songs/dupstep/preview_69.mp3
# Downloaded ./songs/dupstep/preview_70.mp3
# Downloaded ./songs/dupstep/preview_71.mp3
# Downloaded ./songs/dupstep/preview_72.mp3
# Downloaded ./songs/dupstep/preview_73.mp3
# Downloaded ./songs/dupstep/preview_74.mp3
# Downloaded ./songs/dupstep/preview_75.mp3
# Downloaded ./songs/dupstep/preview_76.mp3
# Downloaded ./songs/dupstep/preview_77.mp3
# Downloaded ./songs/dupstep/preview_78.mp3
# Downloaded ./songs/dupstep/preview_79.mp3
# Downloaded ./songs/dupstep/preview_80.mp3
# Downloaded ./songs/dupstep/preview_81.mp3
# Downloaded ./songs/dupstep/preview_82.mp3
# Downloaded ./songs/dupstep/preview_83.mp3
# Downloaded ./songs/dupstep/preview_84.mp3
# Folder already exists: ./songs/psytrance
# Downloaded ./songs/psytrance/preview_1.mp3
# Downloaded ./songs/psytrance/preview_2.mp3
# Downloaded ./songs/psytrance/preview_3.mp3
# Downloaded ./songs/psytrance/preview_4.mp3
# Downloaded ./songs/psytrance/preview_5.mp3
# Downloaded ./songs/psytrance/preview_6.mp3
# Downloaded ./songs/psytrance/preview_7.mp3
# Downloaded ./songs/psytrance/preview_8.mp3
# Downloaded ./songs/psytrance/preview_9.mp3
# Downloaded ./songs/psytrance/preview_10.mp3
# Downloaded ./songs/psytrance/preview_11.mp3
# Downloaded ./songs/psytrance/preview_12.mp3
# Downloaded ./songs/psytrance/preview_13.mp3
# Downloaded ./songs/psytrance/preview_14.mp3
# Downloaded ./songs/psytrance/preview_15.mp3
# Downloaded ./songs/psytrance/preview_16.mp3
# Downloaded ./songs/psytrance/preview_17.mp3
# Downloaded ./songs/psytrance/preview_18.mp3
# Downloaded ./songs/psytrance/preview_19.mp3
# Downloaded ./songs/psytrance/preview_20.mp3
# Downloaded ./songs/psytrance/preview_21.mp3
# Downloaded ./songs/psytrance/preview_22.mp3
# Downloaded ./songs/psytrance/preview_23.mp3
# Downloaded ./songs/psytrance/preview_24.mp3
# Downloaded ./songs/psytrance/preview_25.mp3
# Downloaded ./songs/psytrance/preview_26.mp3
# Downloaded ./songs/psytrance/preview_27.mp3
# Downloaded ./songs/psytrance/preview_28.mp3
# Downloaded ./songs/psytrance/preview_29.mp3
# Downloaded ./songs/psytrance/preview_30.mp3
# Downloaded ./songs/psytrance/preview_31.mp3
# Downloaded ./songs/psytrance/preview_32.mp3
# Downloaded ./songs/psytrance/preview_33.mp3
# Downloaded ./songs/psytrance/preview_34.mp3
# Downloaded ./songs/psytrance/preview_35.mp3
# Downloaded ./songs/psytrance/preview_36.mp3
# Downloaded ./songs/psytrance/preview_37.mp3
# Downloaded ./songs/psytrance/preview_38.mp3
# Downloaded ./songs/psytrance/preview_39.mp3
